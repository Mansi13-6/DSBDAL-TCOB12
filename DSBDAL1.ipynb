# %%
import pandas as pd 
df=pd.read_excel("/home/ubuntu/Downloads/employee_income.xlsx")
print(df)
print(df.describe())
print(df.head(5))
print(df.tail(5))
# Out:
#     age  experience  income
# 0    50           5   45118
# 1    36           9   41691
# 2    29           3   35994
# 3    42           5   41614
# 4    40          12   51474
# 5    44          14   57092
# 6    32           1   31661
# 7    32           9   42378
# 8    45          11   50099
# 9    57           1   35800
# 10   45           9   49959
# 11   24          13   48575
# 12   43           3   37504
# 13   23          13   47998
# 14   45          14   53954
# 15   51          14   56945
# 16   59           7   51047
# 17   23          13   44204
# 18   42           6   41331
# 19   54          11   55691
# 20   33           8   41673
# 21   43          13   50970
# 22   46           7   46356
# 23   48           4   42981
# 24   49          12   52390
# 25   37           1   33440
# 26   36          14   49828
# 27   24           4   30702
# 28   58           7   49393
# 29   28           9   39770
# 30   42           8   46088
# 31   30          11   42706
# ...

# %%
import pandas as pd
df=pd.read_csv("/home/ubuntu/Downloads/employee_income.csv")
print(df)
print(df.info())
# Out:
#     age  experience  income
# 0    50           5   45118
# 1    36           9   41691
# 2    29           3   35994
# 3    42           5   41614
# 4    40          12   51474
# 5    44          14   57092
# 6    32           1   31661
# 7    32           9   42378
# 8    45          11   50099
# 9    57           1   35800
# 10   45           9   49959
# 11   24          13   48575
# 12   43           3   37504
# 13   23          13   47998
# 14   45          14   53954
# 15   51          14   56945
# 16   59           7   51047
# 17   23          13   44204
# 18   42           6   41331
# 19   54          11   55691
# 20   33           8   41673
# 21   43          13   50970
# 22   46           7   46356
# 23   48           4   42981
# 24   49          12   52390
# 25   37           1   33440
# 26   36          14   49828
# 27   24           4   30702
# 28   58           7   49393
# 29   28           9   39770
# 30   42           8   46088
# 31   30          11   42706
# ...

# %%
import pandas as pd

data = {
    "Duration": {
        "0": 60, "1": 60, "2": 60, "3": 45, "4": 45, "5": 60
    },
    "Pulse": {
        "0": 110, "1": 117, "2": 103, "3": 109, "4": 117, "5": 102
    },
    "Maxpulse": {
        "0": 130, "1": 145, "2": 135, "3": 175, "4": 148, "5": 127
    },
    "Calories": {
        "0": 409, "1": 479, "2": 340, "3": 282, "4": 406, "5": 300
    }
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
import pandas as pd
df=pd.read_excel("/home/ubuntu/Downloads/Demo Marks.xlsx")
df.dropna(inplace=True)
print(df)
# Out:
#     Roll no          Name of Student  \
# 0         1        RAVAL MEET MAHESH
# 1         2    HUMBE BHAKTI RAJENDRA
# 3         4    THAKARE MRUNALI VINOD
# 4         5  BHONGALE OMKAR MADHUKAR
# 5         6  THETE SANJIVANI SANTOSH
# ..      ...                      ...
# 69       70    KUNWAR ABHIJEET SINGH
# 70       71           TUPE OM KISHOR
# 71       72     DARWEY RUDRA GUNWANT
# 72       73     JAGTAP HARISH YUVRAJ
# 73       74             ASHUTOSH RAJ
#
#     Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                          1131  80.785714        29.0
# 1                                          1107  79.071429        29.0
# 3                                          1077  76.928571        28.0
# 4                                          1064  76.000000        28.0
# 5                                          1129  80.642857        29.0
# ..                                          ...        ...         ...
# ...

# %%
import pandas as pd
df=pd.read_excel("/home/ubuntu/Downloads/StudentDirtyDataVer1.xlsx")
df['DOJ'] = pd.to_datetime(df['DOJ'])
print(df.to_string())
# Out:
#   StudentName      ID        DOJ Grade  Age
# 0        Joey  114532 2020-01-06     A   18
# 1   Catherine  114533 2021-02-11     A   19
# 2        Mary  114534 2022-09-03     B   18
# 3       James  114535 2023-07-06     A   18
# 4    Michelle  114536 2020-04-18     B   20
# 5   Catherine  114533 2020-03-16     A   19
# 6         NaN  114537        NaT     A   18

# %%
import pandas as pd
df=pd.read_excel("/home/ubuntu/Downloads/StudentDirtyDataVer1.xlsx")
print(df)
df.loc[4, "Age"]=19
print(df)
# Out:
#   StudentName      ID                  DOJ Grade  Age
# 0        Joey  114532  2020-01-06 00:00:00     A   18
# 1   Catherine  114533  2021-02-11 00:00:00     A   19
# 2        Mary  114534  2022-09-03 00:00:00     B   18
# 3       James  114535  2023-07-06 00:00:00     A   18
# 4    Michelle  114536  2020-04-18 00:00:00     B   20
# 5   Catherine  114533  2020-03-16 00:00:00     A   19
# 6         NaN  114537                  NaT     A   18
#   StudentName      ID                  DOJ Grade  Age
# 0        Joey  114532  2020-01-06 00:00:00     A   18
# 1   Catherine  114533  2021-02-11 00:00:00     A   19
# 2        Mary  114534  2022-09-03 00:00:00     B   18
# 3       James  114535  2023-07-06 00:00:00     A   18
# 4    Michelle  114536  2020-04-18 00:00:00     B   19
# 5   Catherine  114533  2020-03-16 00:00:00     A   19
# 6         NaN  114537                  NaT     A   18

# %%
import pandas as pd
df=pd.read_excel("/home/ubuntu/Downloads/StudentDirtyDataVer1.xlsx")
print(df)
print(df.duplicated(keep="first"))
# Out:
#   StudentName      ID                  DOJ Grade  Age
# 0        Joey  114532  2020-01-06 00:00:00     A   18
# 1   Catherine  114533  2021-02-11 00:00:00     A   19
# 2        Mary  114534  2022-09-03 00:00:00     B   18
# 3       James  114535  2023-07-06 00:00:00     A   18
# 4    Michelle  114536  2020-04-18 00:00:00     B   20
# 5   Catherine  114533  2021-02-11 00:00:00     A   19
# 6         NaN  114537                  NaT     A   18
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
import pandas as pd
df=pd.read_excel("/home/ubuntu/Downloads/StudentDirtyDataVer1.xlsx")
print(df)
print(df.duplicated (keep="last"))
# Out:
#   StudentName      ID                  DOJ Grade  Age
# 0        Joey  114532  2020-01-06 00:00:00     A   18
# 1   Catherine  114533  2021-02-11 00:00:00     A   19
# 2        Mary  114534  2022-09-03 00:00:00     B   18
# 3       James  114535  2023-07-06 00:00:00     A   18
# 4    Michelle  114536  2020-04-18 00:00:00     B   20
# 5   Catherine  114533  2021-02-11 00:00:00     A   19
# 6         NaN  114537                  NaT     A   18
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
import pandas as pd
df=pd.read_excel("/home/ubuntu/Downloads/StudentDirtyDataVer1.xlsx")
print(df)
print(df.duplicated(keep=False))
# Out:
#   StudentName      ID                  DOJ Grade  Age
# 0        Joey  114532  2020-01-06 00:00:00     A   18
# 1   Catherine  114533  2021-02-11 00:00:00     A   19
# 2        Mary  114534  2022-09-03 00:00:00     B   18
# 3       James  114535  2023-07-06 00:00:00     A   18
# 4    Michelle  114536  2020-04-18 00:00:00     B   20
# 5   Catherine  114533  2021-02-11 00:00:00     A   19
# 6         NaN  114537                  NaT     A   18
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
import pandas as pd
df=pd.read_json("/home/ubuntu/Downloads/sample_students.json")
print(df)
# Out:
#    RollNo       Name         DOJ Grade  Age
# 0       1       Joey  2020-01-06     A   18
# 1       2  Catherine  01-06-2020     A   19
# 2       3       Mary  03-06-2020     B   18
# 3       4      James   01-Jun-20     A   18
# 4       5   Michelle  2020/06/01     B   20

# %%
df=pd.read_table("/home/ubuntu/Downloads/review.txt", names=["Reviews"])
